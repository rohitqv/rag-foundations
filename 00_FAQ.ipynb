# %% [markdown]
# dense embedding vector powering semantic search

# %% [markdown]
# sparse vectors powering keyword search

# %% [markdown]
# HNSW index to power ANN search

# %% [markdown]
# What is sentence transformers?
